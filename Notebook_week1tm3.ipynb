# %% [markdown]
# # Notebook week 1 t/m 3

# %% [markdown]
# ## Introduction

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df_step = pd.read_csv("steps.csv", sep=";")
df_survey = pd.read_csv('survey.csv')

df = df_survey.merge(df_step, on = "id")
df.head(10)
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
# 5   6        Lille    Male  35-44        1          1           Vocational
# 6   7  Montpellier    Male  25-34        2          2  Master or doctorate
# 7   8     Bordeaux  Female  25-34        3          4  Master or doctorate
# 8   9        Lille  Female  35-44        4          4           Vocational
# 9  10        Lille  Female  25-34        2          2  Master or doctorate
#
#    height  weight  20-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  7-5-2014  \
# ...

# %%
df.describe()
# Out:
#                id     hh_size   education      height      weight  \
# count  929.000000  929.000000  929.000000  928.000000  927.000000
# mean   465.000000    2.342304    2.530678  171.668103   72.833873
# std    268.323499    1.226129    1.274491    9.080235   25.902717
# min      1.000000    1.000000    1.000000  145.000000    6.000000
# 25%    233.000000    1.000000    1.000000  165.000000   61.000000
# 50%    465.000000    2.000000    2.000000  172.000000   71.000000
# 75%    697.000000    3.000000    4.000000  179.000000   81.000000
# max    929.000000   11.000000    5.000000  195.000000  700.000000
#
#           20-6-2013     21-6-2013     22-6-2013     23-6-2013     24-6-2013  \
# count     24.000000    243.000000    278.000000    296.000000    354.000000
# mean    3642.416667   9034.724280  10889.636691   7402.847973   8110.370056
# std     3951.910368   6412.774483   6283.204309   6733.291773   5495.536639
# ...

# %% [markdown]
# ## Data cleaning

# %%
df['weight']=df['weight'].replace(700,np.nan)

# %%
df['steps_mean']=df.iloc[:,9:336].mean(axis=1)
df.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight  20-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  8-5-2014  \
# 0   178.0    98.0        NaN  ...       NaN       NaN       NaN       NaN
# 1   180.0    77.0        NaN  ...       NaN       NaN       NaN       NaN
# 2   180.0    83.0        NaN  ...    4364.0       NaN       NaN       NaN
# 3   178.0    80.0        NaN  ...       NaN       NaN       NaN       NaN
# 4   167.0    61.0        NaN  ...       NaN       NaN       NaN       NaN
#
#    9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014    steps_mean
# ...

# %%
sns.displot(x="steps_mean", kde=False, data=df) 
plt.title("Mean steps per day")
plt.xlabel("Mean steps")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x="steps_mean", data=df)
plt.title("Mean steps per day")
plt.xlabel("Mean steps")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
print('Median = '+str(df['steps_mean'].median()))
print('Mean = '+str(df['steps_mean'].mean()))
print('St Dev. = '+str(df['steps_mean'].std()))
# Out:
# Median = 6245.006060606061
# Mean = 7036.627484984338
# St Dev. = 7396.87900787018

# %%
df=df[df['steps_mean']<100000]

# %%
print('Median = '+str(df['steps_mean'].median()))
print('Mean = '+str(df['steps_mean'].mean()))
print('St Dev. = '+str(df['steps_mean'].std()))
# Out:
# Median = 6244.931601731601
# Mean = 6825.928380530858
# St Dev. = 3696.491961554726

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation=45)
sns.violinplot(x='age',y='steps_mean',data=df)
plt.title('Mean steps for each age group')
plt.xlabel('Age group')
plt.ylabel('Mean steps')
plt.show()

# %% [markdown]
# De groep onder 25 jaar loopt gemiddeld minder stappen dan de groep 55-64. Naarmaten mensen ouder worden neemt het aantal stappen ook weer af.

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation=45)
sns.boxplot(x='education_1',y='steps_mean',data=df)
sns.swarmplot(x='education_1',y='steps_mean', size=3, data=df)
plt.title('Mean steps for each age group')
plt.xlabel('Age group')
plt.ylabel('Mean steps')
plt.show()

# %% [markdown]
# Het niveau waarop iemand is geschoold heeft geen invloed op de aantal stappen die iemand maakt.

# %% [markdown]
# ## Feature engineering

# %%
sns.scatterplot(x="steps_mean", data=df)
plt.title("Mean steps per day")
plt.xlabel("Mean steps")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * scatterplot werkt niet, begrijp niet waarom *

# %% [markdown]
# ## Exploratory data analysis

# %%
corr = df[['steps_mean', 'height', 'weight', 'education']].corr()
corr
# Out:
#             steps_mean    height    weight  education
# steps_mean    1.000000 -0.097515 -0.085936   0.041107
# height       -0.097515  1.000000  0.514950  -0.043715
# weight       -0.085936  0.514950  1.000000  -0.002341
# education     0.041107 -0.043715 -0.002341   1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap="YlGnBu") 
plt.show()

# %% [markdown]
# Er is geen correlatie te zien tussen het gemiddelde aantal stappen per dag en gewicht, lengte of opleidings niveau. Wel laat deze plot zien dat er een verband is tussen lengte en gewicht.

# %% [markdown]
# ## Predictive model

# %% [markdown]
# Met liniare regressie kun je een liniair verband tussen twee variabelen vaststellen.

# %%
x = df[['steps_mean']]
y = df[['height', 'weight', 'age', 'education']]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3,random_state=23)

# %%
lm = LinearRegression() 

lm = lm.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/dp/020xg0d11clcdstfhz0fd8hm0000gn/T/ipykernel_57556/3810544748.py in <module>
#       1 lm = LinearRegression()
#       2
# ----> 3 lm = lm.fit(x_train, y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     574                 y = check_array(y, **check_y_params)
#     575             else:
# --> 576                 X, y = check_X_y(X, y, **check_params)
# ...

# %% [markdown]
# ## Evaluation

# %%
y_test_p = lm.predict(x_test)
r2_score(y_test, y_test_p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/dp/020xg0d11clcdstfhz0fd8hm0000gn/T/ipykernel_57556/2426350860.py in <module>
# ----> 1 y_test_p = lm.predict(x_test)
#       2 r2_score(y_test, y_test_p)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     344
#     345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# --> 346         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     347
#     348     def predict(self, X):
#
# ...

# %% [markdown]
# * bij het maken van de test set is er een error die ik niet weg krijg, hierdoor heeft de test geen uitslag *
